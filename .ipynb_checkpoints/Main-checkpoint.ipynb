# %%
from qiskit import QuantumCircuit
from Functions.helpers import *
SAES_GATE_LOG = []
key = []

# %%
plaintext = '1001011011001111'   # 16 bits
round_key = '1010011100111011'   # 16 bits (if needed)

total_qubits = 68
qc = QuantumCircuit(total_qubits, name="SAES_stage1_SubNibble")

# 1) place plaintext on 0..15
apply_plaintext(qc, plaintext)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 qc = QuantumCircuit(total_qubits, name="SAES_stage1_SubNibble")
#       7 # 1) place plaintext on 0..15
# ----> 8 apply_plaintext(qc, plaintext,SAES_GATE_LOG)
#
# TypeError: apply_plaintext() takes 2 positional arguments but 3 were given
