# %%
"""
============================================================
 PRINCE Block Cipher — Reversible Quantum Circuit
 Module 1: Pre-whitening layer  (XOR k0, XOR RC0, XOR k1)
============================================================

 Cipher parameters:
   - Plaintext  : 64 bits
   - Key K      : 128 bits  →  split into k0 (high 64) and k1 (low 64)
   - k0'        : derived from k0 via the PRINCE key schedule

 What this module implements (left edge of the block diagram):
   ┌──────────────────────────────────────────────────────┐
   │  state = plaintext ⊕ k0 ⊕ RC0 ⊕ k1                  │
   └──────────────────────────────────────────────────────┘

 Why this is reversible:
   Every XOR is implemented with CNOT (or Pauli-X for fixed
   constants).  Both gates are self-inverse, so the entire
   circuit is its own inverse up to input initialisation.

 Qubit registers (256 qubits total):
   state[0..63]  — 64-bit data path  (plaintext flows in, intermediate
                   state flows out; will carry ciphertext at the end)
   k0[0..63]     — key half k0  (loaded once, reused each time the
                   oracle is queried — in Grover it will be in superposition)
   k1[0..63]     — key half k1  (same note as k0)
   k0p[0..63]    — k0 prime  (pre-computed from k0; needed for the
                   post-whitening step at the very end of PRINCE)

 Bit convention throughout:
   qubit[0]  ↔  bit 0  (LSB) of the corresponding integer
   qubit[63] ↔  bit 63 (MSB)

 Simulation backend:
   Aer 'stabilizer' method.
   The pre-whitening layer uses ONLY Clifford gates (X and CNOT),
   so the stabilizer simulator is exact and runs in polynomial time
   regardless of qubit count.  No statevector explosion.

Dependencies:
   pip install qiskit qiskit-aer
"""
# Out:
# "\n============================================================\n PRINCE Block Cipher — Reversible Quantum Circuit\n Module 1: Pre-whitening layer  (XOR k0, XOR RC0, XOR k1)\n============================================================\n\n Cipher parameters:\n   - Plaintext  : 64 bits\n   - Key K      : 128 bits  →  split into k0 (high 64) and k1 (low 64)\n   - k0'        : derived from k0 via the PRINCE key schedule\n\n What this module implements (left edge of the block diagram):\n   ┌──────────────────────────────────────────────────────┐\n   │  state = plaintext ⊕ k0 ⊕ RC0 ⊕ k1                  │\n   └──────────────────────────────────────────────────────┘\n\n Why this is reversible:\n   Every XOR is implemented with CNOT (or Pauli-X for fixed\n   constants).  Both gates are self-inverse, so the entire\n   circuit is its own inverse up to input initialisation.\n\n Qubit registers (256 qubits total):\n   state[0..63]  — 64-bit data path  (plaintext flows in, intermediate\n                   state flows out; will carry ciphertext at the end)\n   k0[0..63]     — key half k0  (loaded once, reused each time the\n                   oracle is queried — in Grover it will be in superposition)\n   k1[0..63]     — key half k1  (same note as k0)\n   k0p[0..63]    — k0 prime  (pre-computed from k0; needed for the\n                   post-whitening step at the very end of PRINCE)\n\n Bit convention throughout:\n   qubit[0]  ↔  bit 0  (LSB) of the corresponding integer\n   qubit[63] ↔  bit 63 (MSB)\n\n Simulation backend:\n   Aer 'stabilizer' method.\n   The pre-whitening layer uses ONLY Clifford gates (X and CNOT),\n   so the stabilizer simulator is exact and runs in polynomial time\n   regardless of qubit count.  No statevector explosion.\n\nDependencies:\n   pip install qiskit qiskit-aer\n"

# %%
# ── Standard library ──────────────────────────────────────────────────────────
# (none needed beyond Qiskit)

# ── Qiskit ────────────────────────────────────────────────────────────────────
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit_aer import AerSimulator

from Round import quantum_round, classical_round, quantum_inverse_round, classical_inverse_round
from Helpers import xor_constant_into_register, xor_register_into_register
from Sbox import quantum_s_layer, classical_s_layer, quantum_s_layer_inv, classical_s_layer_inv
from Mbox import quantum_m_layer, quantum_m_layer_inv, classical_m_layer, classical_m_layer_inv
from Functions.helpers import log_gate_stats
GATE_LOG = []

# %%
# ══════════════════════════════════════════════════════════════════════════════
#  SECTION 1 — PRINCE CONSTANTS
# ══════════════════════════════════════════════════════════════════════════════

# Round constants RC0 .. RC10 are fixed 64-bit values derived from the
# fractional part of π.  They are XOR-ed into the state at the start and
# end of every round (and during the pre/post-whitening step for RC0).
# Source: Borghoff et al., "PRINCE – A Low-Latency Block Cipher", ASIACRYPT 2012.

ROUND_CONSTANTS = [
    0x0000000000000000,   # RC0  — all-zero by design (XOR is identity here)
    0x13198A2E03707344,   # RC1
    0xA4093822299F31D0,   # RC2
    0x082EFA98EC4E6C89,   # RC3
    0x452821E638D01377,   # RC4
    0xBE5466CF34E90C6C,   # RC5  — also called α, used in the middle round
    0x7EF84F78FD955CB1,   # RC6
    0x85840851F1AC43AA,   # RC7
    0xC882D32F25323C54,   # RC8
    0x64A51195E0E3610D,   # RC9
    0xD3B5A399CA0C2399,   # RC10
    0xc0ac29b7c97c50dd,   # RC11
]

# Convenience alias used in the pre/post-whitening layer
RC0 = ROUND_CONSTANTS[0]   # == 0  (XOR with RC0 adds zero gates to the circuit)

# %%
# ══════════════════════════════════════════════════════════════════════════════
#  SECTION 2 — CLASSICAL HELPER: KEY SCHEDULE
# ══════════════════════════════════════════════════════════════════════════════

def prince_key_schedule(K_128bit):
    """
    Derive k0, k1, and k0' from the 128-bit master key K.

    PRINCE key schedule (from the spec):
        k0  = K[127:64]          — upper 64 bits of K
        k1  = K[63:0]            — lower 64 bits of K
        k0' = ROR64(k0, 1) ⊕ (k0 >> 63)

    The ROR (rotate-right-by-1) plus the extra XOR with the top bit
    is equivalent to:
        k0' = (k0 >> 1)          — shift right, dropping bit 0
            | (k0 << 63)         — rotate the dropped bit into position 63
            ^ (k0 >> 63)         — XOR with original bit 63
    All arithmetic is mod 2^64.

    k0' is used only in the post-whitening step at the very end of
    encryption; it is pre-computed here so the quantum register can be
    loaded once and held throughout the circuit.

    Parameters
    ----------
    K_128bit : int   128-bit master key (Python integer)

    Returns
    -------
    k0, k1, k0_prime : (int, int, int)   each a 64-bit Python integer
    """
    MASK64 = (1 << 64) - 1

    k0 = (K_128bit >> 64) & MASK64   # high half
    k1 =  K_128bit        & MASK64   # low half

    # ROR64(k0, 1): bit i of k0 maps to bit (i-1) mod 64 of k0'
    ror1     = ((k0 >> 1) | (k0 << 63)) & MASK64
    k0_prime = ror1 ^ (k0 >> 63)         # XOR with the original MSB

    return k0, k1, k0_prime

# %%
# ══════════════════════════════════════════════════════════════════════════════
#  SECTION 4 — PRE-WHITENING CIRCUIT BUILDER
# ══════════════════════════════════════════════════════════════════════════════

def build_prewhitening_circuit(plaintext_64bit, K_128bit):
    """
    Build the reversible quantum circuit for PRINCE pre-whitening:

        state  =  plaintext  ⊕  k0  ⊕  RC0  ⊕  k1

    This corresponds to the very first operations in the PRINCE block
    diagram (left side): the two circles labelled ⊕ before R1.

    The circuit has 256 qubits organised as four 64-qubit registers:

        ┌─────────────────────────────────────────────────────────┐
        │  state  — carries the data (plaintext → intermediate)   │
        │  k0     — first key half (controls XOR into state)      │
        │  k1     — second key half (controls XOR into state)     │
        │  k0p    — k0 prime (stored here, used in post-whitening)│
        └─────────────────────────────────────────────────────────┘

    Gate sequence:
        1. Load plaintext  →  X gates on state  where plaintext bit = 1
        2. Load k0         →  X gates on k0     where k0 bit = 1
        3. Load k1         →  X gates on k1     where k1 bit = 1
        4. Load k0'        →  X gates on k0p    where k0' bit = 1
        5. state ^= k0     →  64 CNOT gates  (k0  → state)
        6. state ^= RC0    →  X gates on state for set bits of RC0
                              (RC0 = 0, so this adds ZERO gates)
        7. state ^= k1     →  64 CNOT gates  (k1  → state)
        8. Measure state   →  64 measure operations into classical register

    Parameters
    ----------
    plaintext_64bit : int   64-bit plaintext
    K_128bit        : int   128-bit master key

    Returns
    -------
    qc       : QuantumCircuit   the assembled circuit (with measurement)
    k0       : int              64-bit k0 (for external verification)
    k1       : int              64-bit k1 (for external verification)
    k0_prime : int              64-bit k0' (for external verification)
    """

    # ── Derive key halves ─────────────────────────────────────────────────────
    k0, k1, k0_prime = prince_key_schedule(K_128bit)

    # ── Allocate quantum registers ────────────────────────────────────────────
    state = QuantumRegister(64, name='state')   # data path
    anc   = QuantumRegister(16 * 14, name='anc')
    qk0   = QuantumRegister(64, name='k0')      # key half 0
    qk1   = QuantumRegister(64, name='k1')      # key half 1
    qk0p  = QuantumRegister(64, name='k0p')     # k0 prime (post-whitening)

    # Classical register captures the 64-bit state after pre-whitening
    creg  = ClassicalRegister(64, name='out')

    qc = QuantumCircuit(state, anc, qk0, qk1, qk0p, creg)

    # ── Step 1: Initialise state register with plaintext ─────────────────────
    qc.barrier(label="Init: plaintext → state")
    for bit in range(64):
        if (plaintext_64bit >> bit) & 1:
            qc.x(state[bit])
    log_gate_stats("Plain Text", qc, GATE_LOG)
    # ── Step 2: Initialise k0 register ───────────────────────────────────────
    qc.barrier(label="Init: k0 → k0 register")
    for bit in range(64):
        if (k0 >> bit) & 1:
            qc.x(qk0[bit])

    # ── Step 3: Initialise k1 register ───────────────────────────────────────
    qc.barrier(label="Init: k1 → k1 register")
    for bit in range(64):
        if (k1 >> bit) & 1:
            qc.x(qk1[bit])

    # ── Step 4: Initialise k0' register ──────────────────────────────────────
    qc.barrier(label="Init: k0' → k0p register")
    for bit in range(64):
        if (k0_prime >> bit) & 1:
            qc.x(qk0p[bit])

    # ── Step 5: state ^= k0 ──────────────────────────────────────────────────
    qc.barrier(label="XOR k0 into state")
    xor_register_into_register(qc, qk0, state)
    log_gate_stats("Add k0", qc, GATE_LOG)

    # ── Step 5.1: state ^= k1 ──────────────────────────────────────────────────
    qc.barrier(label="XOR k1 into state")
    xor_register_into_register(qc, qk1, state)
    log_gate_stats("Add k1", qc, GATE_LOG)
    
    # ── Step 6: state ^= RC0 ─────────────────────────────────────────────────
    qc.barrier(label="XOR RC0 into state")
    xor_constant_into_register(qc, state, RC0)   # no-op because RC0 == 0
    log_gate_stats("Add RC0", qc, GATE_LOG)
    
    # Round 1 
    for i in range(1,6):
        quantum_round(i,  qc, state, anc, qk1, ROUND_CONSTANTS[i])
        log_gate_stats(f"Round {i}", qc, GATE_LOG)

    qc.barrier(label=f"Middle Sbox")
    quantum_s_layer(qc, state, anc)
    log_gate_stats(f"Middle Sbox", qc, GATE_LOG)
    
    qc.barrier(label=f"Middle Mbox")
    quantum_m_layer(qc, state)
    log_gate_stats(f"Middle Mbox", qc, GATE_LOG)
    
    qc.barrier(label=f"Middle Sbox inv")
    quantum_s_layer_inv(qc, state, anc)
    log_gate_stats(f"Middle Sbox inverse", qc, GATE_LOG)
    
    for i in range(6,11):
        quantum_inverse_round(i, qc, state, anc, qk1, ROUND_CONSTANTS[i])
        log_gate_stats(f"Inverse Round {i}", qc, GATE_LOG)

    
    qc.barrier(label="XOR RC11 into state")
    xor_constant_into_register(qc, state, ROUND_CONSTANTS[11])
    log_gate_stats(f"Last RC0", qc, GATE_LOG)
    
    qc.barrier(label="XOR k1 into state")
    xor_register_into_register(qc, qk1, state)
    log_gate_stats(f"Last K0", qc, GATE_LOG)

    
    qc.barrier(label="XOR K0_Prime into state")
    xor_register_into_register(qc, qk0p, state)
    log_gate_stats(f"Last K0_prime", qc, GATE_LOG)
    
    # ── Step 8: Measure the state register ───────────────────────────────────
    qc.barrier(label="Measure state")
    qc.measure(state, creg)

    return qc, k0, k1, k0_prime, GATE_LOG

# %%
# ══════════════════════════════════════════════════════════════════════════════
#  SECTION 5 — CLASSICAL REFERENCE IMPLEMENTATION
# ══════════════════════════════════════════════════════════════════════════════

def classical_prewhitening(plaintext_64bit, K_128bit):
    """
    Pure-Python reference for PRINCE pre-whitening.
    Used to cross-check the quantum circuit output.

        state = plaintext ⊕ k0 ⊕ RC0 ⊕ k1

    Parameters
    ----------
    plaintext_64bit : int   64-bit plaintext
    K_128bit        : int   128-bit master key

    Returns
    -------
    state    : int   64-bit intermediate state after pre-whitening
    k0       : int   64-bit k0
    k1       : int   64-bit k1
    k0_prime : int   64-bit k0'
    """
    MASK64 = (1 << 64) - 1
    k0, k1, k0_prime = prince_key_schedule(K_128bit)

    state = plaintext_64bit & MASK64
    state ^= k0
    state ^= k1
    state ^= RC0    # == 0, so state unchanged; included for structural clarity

    for i in range(1,6):
        state = classical_round(i, state, k1, ROUND_CONSTANTS[i])

    state = classical_s_layer(state)
    state = classical_m_layer(state)
    state = classical_s_layer_inv(state)

    for i in range(6,11):
        state = classical_inverse_round(i,state,k1, ROUND_CONSTANTS[i])
    
    state ^= ROUND_CONSTANTS[11]
    state ^= k1
    state ^= k0_prime
    
    return state, k0, k1, k0_prime

# %%
# ══════════════════════════════════════════════════════════════════════════════
#  SECTION 6 — SIMULATION HELPER
# ══════════════════════════════════════════════════════════════════════════════

def bitstring_to_int(bitstring):
    """
    Convert an Aer measurement bitstring to a Python integer.

    Aer returns classical register bits MSB-first:
        bitstring[0]  = creg[63]  = state qubit 63  = integer bit 63
        bitstring[63] = creg[0]   = state qubit 0   = integer bit 0

    Therefore  int(bitstring, 2)  gives the correct integer directly,
    because int() treats the leftmost character as the most significant bit.

    Example:
        bitstring = '1111111011011100...'  (64 chars)
        int(bitstring, 2) == 0xFEDCBA9876543210   ✓

    Parameters
    ----------
    bitstring : str   64-character '0'/'1' string from Aer counts

    Returns
    -------
    int   64-bit integer
    """
    return int(bitstring, 2)


def simulate(qc, sim):
    result = sim.run(qc, shots=1).result()
    counts = result.get_counts()
    return int(list(counts.keys())[0], 2)

# %%
import matplotlib.pyplot as plt

def plot_gate_usage_per_stage(log):
    """
    Given SAES_GATE_LOG, compute (current - previous)
    and plot a bar chart of gates *used in each stage*.
    """

    stages = [entry['stage'] for entry in log]
    totals  = [entry['total_gates'] for entry in log]

    # Compute per-stage usage
    per_stage = []
    for i in range(len(totals)):
        if i == 0:
            per_stage.append(totals[i])  # first stage
        else:
            per_stage.append(totals[i] - totals[i-1])

    # Bar chart
    plt.figure(figsize=(12, 5))
    plt.bar(stages, per_stage, color='skyblue')

    plt.xticks(rotation=45, ha='right')
    plt.title("Gates Used Per Stage (Incremental)", fontsize=16)
    plt.xlabel("Stage", fontsize=14)
    plt.ylabel("Gates Used in Stage", fontsize=14)
    plt.grid(axis='y', linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.show()

    return per_stage

def draw_circuit(qc):
    qc.draw('mpl', fold = 5)

# %%
# ══════════════════════════════════════════════════════════════════════════════
#  SECTION 7 — MAIN: BUILD, SIMULATE, AND VERIFY
# ══════════════════════════════════════════════════════════════════════════════

if __name__ == "__main__":

    # Aer stabilizer backend — handles any number of Clifford-only qubits
    # exactly, in polynomial time.  We reuse the same simulator object
    # across all tests.
    sim = AerSimulator(method='matrix_product_state')

    # ──────────────────────────────────────────────────────────────────────────
    #  TEST 1 — All-zero key and plaintext
    #  Expected: state = 0 ⊕ 0 ⊕ 0 ⊕ 0 = 0x0000000000000000
    # ──────────────────────────────────────────────────────────────────────────
    print("=" * 62)
    print("  TEST 1 — All-zero plaintext and key")
    print("=" * 62)

    pt1 = 0x0000000000000000
    K1  = 0x00000000000000000000000000000000

    # Classical reference
    ref1, k0_1, k1_1, k0p_1 = classical_prewhitening(pt1, K1)
    print(f"  Plaintext          : 0x{pt1:016X}")
    print(f"  Key K              : 0x{K1:032X}")
    print(f"  k0 (K[127:64])     : 0x{k0_1:016X}")
    print(f"  k1 (K[63:0])       : 0x{k1_1:016X}")
    print(f"  k0' (ROR(k0,1)^msb): 0x{k0p_1:016X}")
    print(f"  RC0                : 0x{RC0:016X}")
    print(f"  Classical result   : 0x{ref1:016X}")

    # Quantum circuit
    qc1, _, _, _, GATE_LOG = build_prewhitening_circuit(pt1, K1)
    meas1 = simulate(qc1, sim)

    print(f"  Quantum result     : 0x{meas1:016X}")
    print(f"  Match              : {'✅ PASS' if meas1 == ref1 else '❌ FAIL'}")

    
    # Resource Estimation
    per_stage_gates = plot_gate_usage_per_stage(GATE_LOG)
    print(per_stage_gates)
    
    # ──────────────────────────────────────────────────────────────────────────
    #  TEST 2 — Non-zero key and plaintext
    #  k0 = pt  →  k0 ⊕ pt = 0  →  state = k1 = 0xFEDCBA9876543210
    # ──────────────────────────────────────────────────────────────────────────
    print()
    print("=" * 62)
    print("  TEST 2 — Non-zero plaintext and key")
    print("=" * 62)

    pt2 = 0x1111111111111111
    K2  = 0x0ABCDEFFEDC123456789BA9876543210

    ref2, k0_2, k1_2, k0p_2 = classical_prewhitening(pt2, K2)
    print(f"  Plaintext          : 0x{pt2:016X}")
    print(f"  Key K              : 0x{K2:032X}")
    print(f"  k0 (K[127:64])     : 0x{k0_2:016X}")
    print(f"  k1 (K[63:0])       : 0x{k1_2:016X}")
    print(f"  k0' (ROR(k0,1)^msb): 0x{k0p_2:016X}")
    print(f"  RC0                : 0x{RC0:016X}")
    print(f"  Classical result   : 0x{ref2:016X}")
    
    GATE_LOG = []
    qc2, _, _, _, GATE_LOG = build_prewhitening_circuit(pt2, K2)
    meas2 = simulate(qc2, sim)

    print(f"  Quantum result     : 0x{meas2:016X}")
    print(f"  Match              : {'✅ PASS' if meas2 == ref2 else '❌ FAIL'}")
    
    # Resource Estimation
    per_stage_gates = plot_gate_usage_per_stage(GATE_LOG)
    print(per_stage_gates)
    
    # ──────────────────────────────────────────────────────────────────────────
    #  TEST 3 — Reversibility
    #  The XOR operations (state^=k0, state^=RC0, state^=k1) must be
    #  reversible.  Applying them then un-applying them must return the
    #  state to the value it had after initialisation (i.e. the plaintext).
    #
    #  Strategy: build a circuit with the initialisation (X gates) followed
    #  by the XOR computation twice.  The second pass is the inverse of the
    #  first, so the net effect on state must be identity → state == plaintext.
    # ──────────────────────────────────────────────────────────────────────────
    print()
    print("=" * 62)
    print("  TEST 3 — Reversibility  (forward ∘ inverse = identity)")
    print("=" * 62)

    # We build the circuit in two parts:
    #   Part A — initialisation (load plaintext, k0, k1, k0')
    #   Part B — XOR computation only (state^=k0, state^=RC0, state^=k1)
    # Reversibility test: run Part A, then Part B, then Part B again.
    # Since Part B is self-inverse (all Clifford), state must equal plaintext.

    k0_3, k1_3, k0p_3 = prince_key_schedule(K2)

    state3 = QuantumRegister(64, name='state')
    qk0_3  = QuantumRegister(64, name='k0')
    qk1_3  = QuantumRegister(64, name='k1')
    qk0p_3 = QuantumRegister(64, name='k0p')
    creg3  = ClassicalRegister(64, name='rev')
    qc3    = QuantumCircuit(state3, qk0_3, qk1_3, qk0p_3, creg3)

    # Part A: initialise all registers (same as build_prewhitening_circuit)
    qc3.barrier(label="Init: plaintext")
    for bit in range(64):
        if (pt2 >> bit) & 1:
            qc3.x(state3[bit])
    qc3.barrier(label="Init: k0")
    for bit in range(64):
        if (k0_3 >> bit) & 1:
            qc3.x(qk0_3[bit])
    qc3.barrier(label="Init: k1")
    for bit in range(64):
        if (k1_3 >> bit) & 1:
            qc3.x(qk1_3[bit])
    qc3.barrier(label="Init: k0p")
    for bit in range(64):
        if (k0p_3 >> bit) & 1:
            qc3.x(qk0p_3[bit])

    # Part B (forward): state ^= k0 ^= RC0 ^= k1
    qc3.barrier(label="Forward: XOR k0")
    xor_register_into_register(qc3, qk0_3, state3)
    qc3.barrier(label="Forward: XOR RC0")
    xor_constant_into_register(qc3, state3, RC0)
    qc3.barrier(label="Forward: XOR k1")
    xor_register_into_register(qc3, qk1_3, state3)

    # Part B (inverse): apply the SAME gates again in REVERSE order.
    # For CNOTs and X gates  g^{-1} = g, so we just replay them in
    # reverse order: state ^= k1 ^= RC0 ^= k0
    qc3.barrier(label="Inverse: XOR k1")
    xor_register_into_register(qc3, qk1_3, state3)
    qc3.barrier(label="Inverse: XOR RC0")
    xor_constant_into_register(qc3, state3, RC0)
    qc3.barrier(label="Inverse: XOR k0")
    xor_register_into_register(qc3, qk0_3, state3)

    # Measure — state must equal the original plaintext
    qc3.barrier(label="Measure")
    qc3.measure(state3, creg3)

    meas3 = simulate(qc3, sim)

    print(f"  Input plaintext              : 0x{pt2:016X}")
    print(f"  After forward + inverse      : 0x{meas3:016X}")
    print(f"  Reversible (should match pt) : {'✅ PASS' if meas3 == pt2 else '❌ FAIL'}")

    
    # ──────────────────────────────────────────────────────────────────────────
    #  CIRCUIT RESOURCE REPORT
    # ──────────────────────────────────────────────────────────────────────────
    print()
    print("=" * 62)
    print("  CIRCUIT RESOURCE REPORT  (test-2 circuit)")
    print("=" * 62)

    print(f"  Qubit registers:")
    for reg in qc2.qregs:
        print(f"    {reg.name:8s}  {reg.size} qubits")

    ops = dict(qc2.count_ops())
    print(f"  Total qubits      : {qc2.num_qubits}")
    print(f"  Classical bits    : {qc2.num_clbits}")
    print(f"  Circuit depth     : {qc2.depth()}")
    print(f"  X  gate count     : {ops.get('x', 0)}")
    print(f"  CNOT gate count   : {ops.get('cx', 0)}")
    print(f"  Measure count     : {ops.get('measure', 0)}")
    print(f"  Toffoli (ccx)     : {ops.get('ccx', 0)}")
    print()
# Out:
# ==============================================================
#   TEST 1 — All-zero plaintext and key
# ==============================================================
#   Plaintext          : 0x0000000000000000
#   Key K              : 0x00000000000000000000000000000000
#   k0 (K[127:64])     : 0x0000000000000000
#   k1 (K[63:0])       : 0x0000000000000000
#   k0' (ROR(k0,1)^msb): 0x0000000000000000
#   RC0                : 0x0000000000000000
#   Classical result   : 0xB607FA70A2065323
# [LOG] Recorded stage 'Plain Text'  → total gates = 1, depth = 0
# [LOG] Recorded stage 'Add k0'  → total gates = 69, depth = 1
# [LOG] Recorded stage 'Add k1'  → total gates = 134, depth = 2
# [LOG] Recorded stage 'Add RC0'  → total gates = 135, depth = 2
# [LOG] Recorded stage 'Round 1'  → total gates = 2068, depth = 896
# [LOG] Recorded stage 'Round 2'  → total gates = 4001, depth = 1790
# [LOG] Recorded stage 'Round 3'  → total gates = 5939, depth = 2684
# [LOG] Recorded stage 'Round 4'  → total gates = 7874, depth = 3578
# [LOG] Recorded stage 'Round 5'  → total gates = 9815, depth = 4472
# [LOG] Recorded stage 'Middle Sbox'  → total gates = 11432, depth = 5352
# [LOG] Recorded stage 'Middle Mbox'  → total gates = 11657, depth = 5364
# [LOG] Recorded stage 'Middle Sbox inverse'  → total gates = 13274, depth = 6244
# [LOG] Recorded stage 'Inverse Round 6'  → total gates = 15221, depth = 7138
# [LOG] Recorded stage 'Inverse Round 7'  → total gates = 17154, depth = 8032
# [LOG] Recorded stage 'Inverse Round 8'  → total gates = 19090, depth = 8926
# [LOG] Recorded stage 'Inverse Round 9'  → total gates = 21025, depth = 9820
# [LOG] Recorded stage 'Inverse Round 10'  → total gates = 22964, depth = 10714
# [LOG] Recorded stage 'Last RC0'  → total gates = 22997, depth = 10715
# [LOG] Recorded stage 'Last K0'  → total gates = 23062, depth = 10716
# [LOG] Recorded stage 'Last K0_prime'  → total gates = 23127, depth = 10717
#   Quantum result     : 0xB607FA70A2065323
#   Match              : ✅ PASS
# [1, 68, 65, 1, 1933, 1933, 1938, 1935, 1941, 1617, 225, 1617, 1947, 1933, 1936, 1935, 1939, 33, 65, 65]
#
# ==============================================================
#   TEST 2 — Non-zero plaintext and key
# ==============================================================
#   Plaintext          : 0x1111111111111111
#   Key K              : 0x0ABCDEFFEDC123456789BA9876543210
#   k0 (K[127:64])     : 0x0ABCDEFFEDC12345
#   k1 (K[63:0])       : 0x6789BA9876543210
#   k0' (ROR(k0,1)^msb): 0x855E6F7FF6E091A2
#   RC0                : 0x0000000000000000
#   Classical result   : 0x44FBFF21F4BA60E1
# [LOG] Recorded stage 'Plain Text'  → total gates = 17, depth = 1
# [LOG] Recorded stage 'Add k0'  → total gates = 185, depth = 5
# [LOG] Recorded stage 'Add k1'  → total gates = 250, depth = 6
# [LOG] Recorded stage 'Add RC0'  → total gates = 251, depth = 6
# [LOG] Recorded stage 'Round 1'  → total gates = 2184, depth = 900
# [LOG] Recorded stage 'Round 2'  → total gates = 4117, depth = 1794
# [LOG] Recorded stage 'Round 3'  → total gates = 6055, depth = 2688
# [LOG] Recorded stage 'Round 4'  → total gates = 7990, depth = 3582
# [LOG] Recorded stage 'Round 5'  → total gates = 9931, depth = 4476
# [LOG] Recorded stage 'Middle Sbox'  → total gates = 11548, depth = 5356
# [LOG] Recorded stage 'Middle Mbox'  → total gates = 11773, depth = 5368
# [LOG] Recorded stage 'Middle Sbox inverse'  → total gates = 13390, depth = 6248
# [LOG] Recorded stage 'Inverse Round 6'  → total gates = 15337, depth = 7142
# [LOG] Recorded stage 'Inverse Round 7'  → total gates = 17270, depth = 8036
# [LOG] Recorded stage 'Inverse Round 8'  → total gates = 19206, depth = 8930
# [LOG] Recorded stage 'Inverse Round 9'  → total gates = 21141, depth = 9824
# [LOG] Recorded stage 'Inverse Round 10'  → total gates = 23080, depth = 10718
# [LOG] Recorded stage 'Last RC0'  → total gates = 23113, depth = 10719
# [LOG] Recorded stage 'Last K0'  → total gates = 23178, depth = 10720
# [LOG] Recorded stage 'Last K0_prime'  → total gates = 23243, depth = 10721
#   Quantum result     : 0x44FBFF21F4BA60E1
#   Match              : ✅ PASS
# [17, 168, 65, 1, 1933, 1933, 1938, 1935, 1941, 1617, 225, 1617, 1947, 1933, 1936, 1935, 1939, 33, 65, 65]
#
# ==============================================================
#   TEST 3 — Reversibility  (forward ∘ inverse = identity)
# ==============================================================
#   Input plaintext              : 0x1111111111111111
#   After forward + inverse      : 0x1111111111111111
#   Reversible (should match pt) : ✅ PASS
#
# ==============================================================
#   CIRCUIT RESOURCE REPORT  (test-2 circuit)
# ==============================================================
#   Qubit registers:
#     state     64 qubits
#     anc       224 qubits
#     k0        64 qubits
#     k1        64 qubits
#     k0p       64 qubits
#   Total qubits      : 480
#   Classical bits    : 64
#   Circuit depth     : 10722
#   X  gate count     : 1398
#   CNOT gate count   : 13920
#   Measure count     : 64
#   Toffoli (ccx)     : 7680

# %%
# qc1.draw('text')

# %%
# ──────────────────────────────────────────────────────────────────────────
#  TEST 4 — α-Reflection Property
#
#  The full PRINCE cipher (FX construction) satisfies:
#
#      Enc(pt, K) = k0'  ⊕  PRINCEcore( pt ⊕ k0,   k1     )
#      Dec(ct, K) = k0   ⊕  PRINCEcore( ct ⊕ k0',  k1 ⊕ α )
#
#  Alpha-reflection is a property of PRINCEcore alone:
#      PRINCEcore(x, k1)⁻¹  =  PRINCEcore(x, k1 ⊕ α)
#
#  To test the full round-trip:
#      1. ct  = Enc(pt, K)           — normal encryption
#      2. rt  = Dec(ct, K)           — decryption as spec defines it:
#                                       k0 ⊕ PRINCEcore(ct ⊕ k0', k1⊕α)
#      3. rt == pt                   — must hold
#
#  In circuit terms, Pass 2 must use:
#      pre-whiten  with k0'          (NOT k0)
#      core key    k1 ⊕ α
#      post-whiten with k0           (NOT k0')
#
#  We implement this by building a dedicated decrypt circuit where we
#  swap the roles of k0 and k0' compared to encryption.
# ──────────────────────────────────────────────────────────────────────────
print()
print("=" * 62)
print("  TEST 4 — α-Reflection  (Enc then Dec = identity)")
print("=" * 62)

ALPHA = 0xC0AC29B7C97C50DD
MASK64 = (1 << 64) - 1

pt4 = 0x1111111111111111
K4  = 0x0ABCDEFFEDC123456789BA9876543210

k0_4, k1_4, k0p_4 = prince_key_schedule(K4)
k1_4_alpha = k1_4 ^ ALPHA

print(f"  Plaintext   : 0x{pt4:016X}")
print(f"  k0          : 0x{k0_4:016X}")
print(f"  k1          : 0x{k1_4:016X}")
print(f"  k0'         : 0x{k0p_4:016X}")
print(f"  k1 ⊕ α      : 0x{k1_4_alpha:016X}")

# ── Classical Pass 1: ct = Enc(pt, K) ────────────────────────────────
ct4, _, _, _ = classical_prewhitening(pt4, K4)
print(f"\n  [Classical]")
print(f"  ct = Enc(pt, K)   : 0x{ct4:016X}")

# ── Classical Pass 2: rt = Dec(ct, K) ────────────────────────────────
# Dec(ct, K) = k0 ⊕ PRINCEcore(ct ⊕ k0', k1⊕α)
# We get this by calling classical_prewhitening with a specially
# constructed key where the upper half is k0' (so it pre-whitens with k0')
# and we manually fix the post-whitening.
#
# Construct K_dec so that prince_key_schedule gives:
#   k0_dec  = k0'   → upper 64 bits = k0'
#   k1_dec  = k1⊕α  → lower 64 bits = k1⊕α
# Then override the post-whitening to use k0 instead of ror1(k0').

def classical_decrypt(ct, k0, k1, k0_prime):
    """
    PRINCE decryption per spec:
        Dec(ct, K) = k0 ⊕ PRINCEcore(ct ⊕ k0',  k1 ⊕ α)
    Implemented by running the same round structure but with:
        pre-whiten  : k0'
        core key    : k1 ⊕ α
        post-whiten : k0   (swapped vs encryption)
    """
    MASK64 = (1 << 64) - 1
    ALPHA  = 0xC0AC29B7C97C50DD
    k1_alpha = k1 ^ ALPHA

    state = ct & MASK64

    # Pre-whitening with k0' (swapped)
    state ^= k0_prime
    state ^= k1_alpha
    state ^= RC0

    # Forward rounds with k1_alpha
    for i in range(1, 6):
        state = classical_round(i, state, k1_alpha, ROUND_CONSTANTS[i])

    # Middle layer
    state = classical_s_layer(state)
    state = classical_m_layer(state)
    state = classical_s_layer_inv(state)

    # Inverse rounds with k1_alpha
    for i in range(6, 11):
        state = classical_inverse_round(i, state, k1_alpha, ROUND_CONSTANTS[i])

    # Post-whitening with k0 (swapped)
    state ^= ROUND_CONSTANTS[11]
    state ^= k1_alpha
    state ^= k0        # k0, not k0'

    return state

rt4_classical = classical_decrypt(ct4, k0_4, k1_4, k0p_4)
print(f"  rt = Dec(ct, K)   : 0x{rt4_classical:016X}")
print(f"  α-reflection      : {'✅ PASS' if rt4_classical == pt4 else '❌ FAIL'}")

# ── Quantum Pass 1: ct = Q_Enc(pt, K) ────────────────────────────────
GATE_LOG = []
qc4_enc, _, _, _, GATE_LOG = build_prewhitening_circuit(pt4, K4)
ct4_quantum = simulate(qc4_enc, sim)
print(f"\n  [Quantum]")
print(f"  ct = Q_Enc(pt, K) : 0x{ct4_quantum:016X}")
print(f"  Matches classical : {'✅ PASS' if ct4_quantum == ct4 else '❌ FAIL'}")

# ── Quantum Pass 2: rt = Q_Dec(ct, K) ────────────────────────────────
# Build a decrypt circuit: pre-whiten with k0', core key k1^alpha,
# post-whiten with k0. We do this by building a new circuit manually
# since build_prewhitening_circuit always uses k0 for pre and k0' for post.

def build_decrypt_circuit(ct_64bit, k0, k1, k0_prime):
    """
    PRINCE decryption circuit:
        pre-whiten  with k0'  and  k1⊕α
        5 forward rounds with k1⊕α
        middle layer
        5 inverse rounds with k1⊕α
        post-whiten with RC11, k1⊕α, k0   (k0 not k0')
    """
    ALPHA    = 0xC0AC29B7C97C50DD
    k1_alpha = k1 ^ ALPHA

    state = QuantumRegister(64, name='state')
    anc   = QuantumRegister(16 * 14, name='anc')
    qk1a  = QuantumRegister(64, name='k1a')   # holds k1^alpha
    qk0   = QuantumRegister(64, name='k0')    # holds k0  (for post-whiten)
    qk0p  = QuantumRegister(64, name='k0p')   # holds k0' (for pre-whiten)
    creg  = ClassicalRegister(64, name='out')

    qc = QuantumCircuit(state, anc, qk0, qk1a, qk0p, creg)

    # Load ciphertext into state
    for bit in range(64):
        if (ct_64bit >> bit) & 1:
            qc.x(state[bit])

    # Load k0 register (used in post-whitening)
    for bit in range(64):
        if (k0 >> bit) & 1:
            qc.x(qk0[bit])

    # Load k1^alpha register
    for bit in range(64):
        if (k1_alpha >> bit) & 1:
            qc.x(qk1a[bit])

    # Load k0' register (used in pre-whitening)
    for bit in range(64):
        if (k0_prime >> bit) & 1:
            qc.x(qk0p[bit])

    # Pre-whitening: ct ^= k0', ^= k1_alpha, ^= RC0
    xor_register_into_register(qc, qk0p, state)   # k0' not k0
    xor_register_into_register(qc, qk1a, state)
    xor_constant_into_register(qc, state, RC0)

    # Forward rounds 1-5 with k1_alpha
    for i in range(1, 6):
        quantum_round(i, qc, state, anc, qk1a, ROUND_CONSTANTS[i])

    # Middle layer
    quantum_s_layer(qc, state, anc)
    quantum_m_layer(qc, state)
    quantum_s_layer_inv(qc, state, anc)

    # Inverse rounds 6-10 with k1_alpha
    for i in range(6, 11):
        quantum_inverse_round(i, qc, state, anc, qk1a, ROUND_CONSTANTS[i])

    # Post-whitening: ^= RC11, ^= k1_alpha, ^= k0  (k0 not k0')
    xor_constant_into_register(qc, state, ROUND_CONSTANTS[11])
    xor_register_into_register(qc, qk1a, state)
    xor_register_into_register(qc, qk0, state)    # k0 not k0'

    qc.measure(state, creg)
    return qc

qc4_dec = build_decrypt_circuit(ct4_quantum, k0_4, k1_4, k0p_4)
rt4_quantum = simulate(qc4_dec, sim)
print(f"  rt = Q_Dec(ct, K) : 0x{rt4_quantum:016X}")
print(f"  α-reflection      : {'✅ PASS' if rt4_quantum == pt4 else '❌ FAIL'}")
# Out:
# ==============================================================
#   TEST 4 — α-Reflection  (Enc then Dec = identity)
# ==============================================================
#   Plaintext   : 0x1111111111111111
#   k0          : 0x0ABCDEFFEDC12345
#   k1          : 0x6789BA9876543210
#   k0'         : 0x855E6F7FF6E091A2
#   k1 ⊕ α      : 0xA725932FBF2862CD
#
#   [Classical]
#   ct = Enc(pt, K)   : 0x44FBFF21F4BA60E1
#   rt = Dec(ct, K)   : 0x1111111111111111
#   α-reflection      : ✅ PASS
# [LOG] Recorded stage 'Plain Text'  → total gates = 17, depth = 1
# [LOG] Recorded stage 'Add k0'  → total gates = 185, depth = 5
# [LOG] Recorded stage 'Add k1'  → total gates = 250, depth = 6
# [LOG] Recorded stage 'Add RC0'  → total gates = 251, depth = 6
# [LOG] Recorded stage 'Round 1'  → total gates = 2184, depth = 900
# [LOG] Recorded stage 'Round 2'  → total gates = 4117, depth = 1794
# [LOG] Recorded stage 'Round 3'  → total gates = 6055, depth = 2688
# [LOG] Recorded stage 'Round 4'  → total gates = 7990, depth = 3582
# [LOG] Recorded stage 'Round 5'  → total gates = 9931, depth = 4476
# [LOG] Recorded stage 'Middle Sbox'  → total gates = 11548, depth = 5356
# [LOG] Recorded stage 'Middle Mbox'  → total gates = 11773, depth = 5368
# [LOG] Recorded stage 'Middle Sbox inverse'  → total gates = 13390, depth = 6248
# [LOG] Recorded stage 'Inverse Round 6'  → total gates = 15337, depth = 7142
# [LOG] Recorded stage 'Inverse Round 7'  → total gates = 17270, depth = 8036
# [LOG] Recorded stage 'Inverse Round 8'  → total gates = 19206, depth = 8930
# [LOG] Recorded stage 'Inverse Round 9'  → total gates = 21141, depth = 9824
# [LOG] Recorded stage 'Inverse Round 10'  → total gates = 23080, depth = 10718
# [LOG] Recorded stage 'Last RC0'  → total gates = 23113, depth = 10719
# [LOG] Recorded stage 'Last K0'  → total gates = 23178, depth = 10720
# [LOG] Recorded stage 'Last K0_prime'  → total gates = 23243, depth = 10721
#
#   [Quantum]
#   ct = Q_Enc(pt, K) : 0x44FBFF21F4BA60E1
#   Matches classical : ✅ PASS
#   rt = Q_Dec(ct, K) : 0x1111111111111111
#   α-reflection      : ✅ PASS
